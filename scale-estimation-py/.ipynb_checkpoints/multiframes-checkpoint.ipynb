# %%
import cv2
import numpy as np
from numpy import array
from lk import DenseMatcherScaleEstimator
from sparse_match import SparseScaleEstimator, RansacScaleEstimator2, RansacScaleEstimator
import os

import pandas as pd
import math

# %%
allshit = None

# %%
# fx = 718.856
# fy = 718.856
# cx = 607.1928
# cy = 185.2157

import math
angle = 4. * math.pi /180.

T_actual_road = np.array([
    [1, 0., 0.],
    [0., math.cos(angle), -math.sin(angle)],
    [0., math.sin(angle), math.cos(angle)]
])

T_road_actual = np.linalg.inv(T_actual_road)

ideal_norm = np.array([ [0.], [1.], [0.] ])
#ideal_norm = T_actual_road.dot(ideal_norm)


fx = 707.0912
fy = 707.0912
cx = 601.8873
cy = 183.1104

cam_mat = np.array([
        [fx, 0, cx],
        [0, fy, cy],
        [0,  0,  1]
    ])
ROI_dense = np.array([
    [500, 230], [700, 230], [800, 330], [400, 330]
])
ROI_dense = ROI_dense.reshape((-1, 1, 2))

ROI_sparse = np.array([
    [500, 230], [700, 230], [800+40, 380], [400-40, 380]
])
ROI_sparse = ROI_sparse.reshape((-1, 1, 2))

actual_height = 1.7

seq_str = '06'
img_data_dir = '/home/cy/Documents/data/kitti/data_odometry_gray/dataset/sequences/{}/image_0/'.format(seq_str)
gt_file = '/home/cy/Documents/data/kitti/data_odometry_poses/{}.txt'.format(seq_str)

nframes = len([f for f in os.listdir(img_data_dir) if f.endswith(".png")])

df_truth = pd.read_csv(gt_file, sep= ' ', header=None)[[3,7,11]]
df_truth.rename(columns={3:'x', 7:'y', 11:'z'}, inplace=True)
df_truth['translation'] = 1.
for i in range(1, len(df_truth)):
    tx = math.pow(df_truth.iloc[i]['x'] - df_truth.iloc[i-1]['x'], 2) + math.pow(df_truth.iloc[i]['y'] - df_truth.iloc[i-1]['y'], 2) + math.pow(df_truth.iloc[i]['z'] - df_truth.iloc[i-1]['z'], 2) 
    df_truth.at[i, 'translation'] = math.sqrt(tx)

seq = int(seq_str)

sample_idx = 0
fn = str(sample_idx).rjust(6, '0')
fnm1 = str(sample_idx+1).rjust(6, '0')
img1= cv2.imread(os.path.join(img_data_dir,"{}.png".format(fn)), 0).astype('float')
img2= cv2.imread(os.path.join(img_data_dir,"{}.png".format(fnm1)), 0).astype('float')
img1 /= 255.
img2 /= 255.

# [[-0.03108007]
#  [ 0.99932888]
#  [ 0.01938621]]
# n2 = array([[-0.01456786],
#        [ 0.46840554],
#        [ 0.00908671]])
# 3.3931844612668813
# scale using roi: 0.797
# [[0.0636999 ]
#  [0.99793658]
#  [0.00805662]]
# n2 = array([[0.03097199],
#        [0.48521395],
#        [0.00391727]])
# 5.082832637658015
# scale using roi+geo constraints: 0.827
# ground truth scale: 0.8307917549542936

# R = array([[ 9.99993673e-01, -3.47749990e-03,  7.48896327e-04],
#        [ 3.47806029e-03,  9.99993672e-01, -7.48286156e-04],
#        [-7.46289423e-04,  7.50886129e-04,  9.99999440e-01]])

# t = array([[ 0.02089309],
#        [ 0.04358919],
#        [-0.99883105]])


matcher = DenseMatcherScaleEstimator(cam_mat, ROI_dense)
#estimator = SparseScaleEstimator(cam_mat, ROI_sparse, 1.7)
estimator = RansacScaleEstimator2(cam_mat, ROI_sparse, 1.7)
# matcher.optimize_scale(R, t, n2[0, 0], n2[1, 0], n2[2, 0], 0., 50, img1, img2, verbose=True)

# %%
start = 751#280#309 #305
end = 900 #311#306
def runall():
    results = []
    hbuffer = []
    timestamps = []
    statistics = []
    
    last_good_n = None
    total_ransac_count = 0

    for i in range(start, end):
#     for i in range(nframes-1):
        try:
            print("processing frame {}".format(i))
            img1 = cv2.imread(os.path.join(img_data_dir, "{}.png".format(str(i).rjust(6, '0'))), 0)
            img2 = cv2.imread(os.path.join(img_data_dir, "{}.png".format(str(i+1).rjust(6, '0'))), 0)

            img1f = img1.astype(float)/255.
            img2f = img2.astype(float)/255.


            cal = estimator.calculate_scale(img1, img2, iterations = 250, accepted_ratio=0.60)
            if cal is None:
                results.append([0, 0])
                statistics.append([0, 0, 0])
            else:
                nunit, n, scale_sparse, R, t, inliers, inliers_ratio, ransac_count = cal
                if ransac_count != 0:
                    total_ransac_count += 1

                gx, gy = matcher.get_image_gradient(img2f)
                gsum = np.sqrt(np.square(gx) + np.square(gy)).sum()

                angle = math.acos(ideal_norm.transpose().dot(n/np.linalg.norm(n)) ) * 180 / math.pi
                print('angle is {} inlier ratio: {}'.format(angle, inliers_ratio))
                if angle > 10. or inliers_ratio < 0.4:
                    raise "error"
#                     results.append([0, 0])
#                     statistics.append([0, 0, 0])

                avg_n = n.copy()
                for idx, nn in enumerate(hbuffer):
                    if i - timestamps[idx] <= 5:
                        avg_n = np.hstack((nn, avg_n))

                count = avg_n.shape[1]
                avg_n = (avg_n.sum(axis=1)/count).reshape((-1, 1))

            #                print(avg_n)
            #                print(n)
            #                 n_opt, scale_dense, sse =  matcher.optimize_scale(R, t, n[0,0], n[1,0], n[2,0], 0, 60, img1f, img2f, verbose=False)
                n_opt, scale_dense, sse =  matcher.optimize_scale(R, t, n[0,0], n[1,0], n[2,0], 0, 50, img1f, img2f, verbose=False)
#                 n_opt, scale_dense, sse =  matcher.optimize_scale(R, t, avg_n[0,0], avg_n[1,0], avg_n[2,0], 0, 50, img1f, img2f, verbose=False)
                angle = math.acos(ideal_norm.transpose().dot(n_opt/np.linalg.norm(n_opt)) ) * 180 / math.pi
                print('dense angle is {}'.format(angle))

                if angle > 20.:
                    raise "error"

                ratio = gsum/sse
                normals_angle = math.acos(nunit.transpose().dot(n_opt/np.linalg.norm(n_opt)) ) * 180 / math.pi

                results.append([scale_sparse, scale_dense])
                statistics.append([ratio, normals_angle, angle])

                hbuffer.append(n_opt)
                timestamps.append(i)
                if len(hbuffer) > 5:
                    hbuffer = hbuffer[1:]
                    timestamps = timestamps[1:]

                    print("buffer size : {}".format(len(hbuffer)))
                
        
        except Exception as e:                
            results.append([0, 0])
            statistics.append([0, 0, 0])
            #print(e)
            #raise e
        
        if nframes % 50 == 0:
            print("Processed {}".format(nframes))
        
        print("-------------------------------------------------")
    
    print("Total ransc count: {}/{}".format(total_ransac_count, end-start))
    return results, statistics

results, statistics = runall()
# Out:
# processing frame 651
# Get RT: (4, 1069)
# there are 30 points
# there are 30 points after filtering
# ransac count: 173
# angle is 3.6896968205824536 inlier ratio: 0.6666666666666666
# dense angle is 3.225673629599992
# -------------------------------------------------
# processing frame 652
# Get RT: (4, 1194)
# there are 47 points
# there are 47 points after filtering
# ransac count: 138
# angle is 2.5222688416486503 inlier ratio: 0.6808510638297872
# dense angle is 2.1437220453510357
# -------------------------------------------------
# processing frame 653
# Get RT: (4, 1264)
# there are 56 points
# there are 56 points after filtering
# ransac count: 214
# angle is 2.4425670142038274 inlier ratio: 0.6964285714285714
# dense angle is 1.4860168792342292
# -------------------------------------------------
# processing frame 654
# Get RT: (4, 1299)
# there are 43 points
# there are 43 points after filtering
# ransac count: 138
# angle is 2.1083475548014525 inlier ratio: 0.7441860465116279
# dense angle is 1.9500597973372744
# -------------------------------------------------
# processing frame 655
# Get RT: (4, 1268)
# there are 50 points
# there are 50 points after filtering
# ransac count: 130
# angle is 4.158089669788085 inlier ratio: 0.72
# -------------------------------------------------
# processing frame 656
# Get RT: (4, 1259)
# there are 54 points
# there are 54 points after filtering
# ransac count: 109
# angle is 12.924141682933119 inlier ratio: 0.6666666666666666
# -------------------------------------------------
# processing frame 657
# Get RT: (4, 1211)
# there are 65 points
# there are 65 points after filtering
# ransac count: 117
# angle is 3.374680251284275 inlier ratio: 0.8461538461538461
# dense angle is 3.5233771718992437
# -------------------------------------------------
# processing frame 658
# Get RT: (4, 1232)
# there are 51 points
# there are 51 points after filtering
# ransac count: 121
# angle is 1.3573065110293947 inlier ratio: 0.8431372549019608
# dense angle is 0.944644039627708
# buffer size : 5
# -------------------------------------------------
# processing frame 659
# Get RT: (4, 1180)
# there are 74 points
# there are 74 points after filtering
# ransac count: 124
# angle is 0.7994605551680245 inlier ratio: 0.6756756756756757
# dense angle is 1.2476633348643644
# buffer size : 5
# -------------------------------------------------
# processing frame 660
# Get RT: (4, 1139)
# there are 73 points
# there are 73 points after filtering
# ransac count: 141
# angle is 2.092428346806202 inlier ratio: 0.7397260273972602
# dense angle is 1.2171267949017905
# buffer size : 5
# -------------------------------------------------
# processing frame 661
# Get RT: (4, 1126)
# there are 53 points
# there are 53 points after filtering
# ransac count: 137
# angle is 2.8439125090321675 inlier ratio: 0.8113207547169812
# dense angle is 2.452404630773002
# buffer size : 5
# -------------------------------------------------
# processing frame 662
# Get RT: (4, 1185)
# there are 70 points
# there are 70 points after filtering
# ransac count: 146
# angle is 1.481905273440363 inlier ratio: 0.6285714285714286
# dense angle is 1.521507673412625
# buffer size : 5
# -------------------------------------------------
# processing frame 663
# Get RT: (4, 1252)
# there are 65 points
# there are 65 points after filtering
# ransac count: 97
# angle is 1.443284125478951 inlier ratio: 0.6923076923076923
# dense angle is 1.8275232593993878
# buffer size : 5
# -------------------------------------------------
# processing frame 664
# Get RT: (4, 1326)
# there are 32 points
# there are 32 points after filtering
# ransac count: 152
# angle is 4.02225570802758 inlier ratio: 0.78125
# dense angle is 4.292772272379678
# buffer size : 5
# -------------------------------------------------
# processing frame 665
# Get RT: (4, 1327)
# there are 41 points
# there are 41 points after filtering
# ransac count: 127
# angle is 1.7221436754179327 inlier ratio: 0.8536585365853658
# dense angle is 1.8822442701674906
# buffer size : 5
# -------------------------------------------------
# processing frame 666
# Get RT: (4, 1353)
# there are 13 points
# there are 13 points after filtering
# ransac count: 20
# angle is 15.495015865555096 inlier ratio: 0.7692307692307693
# -------------------------------------------------
# processing frame 667
# Get RT: (4, 1306)
# there are 31 points
# there are 31 points after filtering
# ransac count: 83
# angle is 4.827509262523929 inlier ratio: 0.6774193548387096
# dense angle is 3.0229481083500294
# buffer size : 5
# -------------------------------------------------
# processing frame 668
# Get RT: (4, 1314)
# there are 32 points
# there are 32 points after filtering
# ransac count: 63
# angle is 4.432261550305553 inlier ratio: 0.75
# dense angle is 4.178121234252055
# buffer size : 5
# -------------------------------------------------
# processing frame 669
# Get RT: (4, 1358)
# there are 32 points
# there are 32 points after filtering
# ransac count: 101
# angle is 6.90883844137297 inlier ratio: 0.65625
# dense angle is 6.2665415963736075
# buffer size : 5
# -------------------------------------------------
# processing frame 670
# Get RT: (4, 1472)
# there are 20 points
# there are 20 points after filtering
# ransac count: 68
# angle is 7.188934770937197 inlier ratio: 0.75
# dense angle is 5.483389043402702
# buffer size : 5
# -------------------------------------------------
# processing frame 671
# Get RT: (4, 1653)
# there are 25 points
# there are 25 points after filtering
# ransac count: 108
# angle is 1.4784414269266795 inlier ratio: 0.76
# dense angle is 2.306738196987284
# buffer size : 5
# -------------------------------------------------
# processing frame 672
# Get RT: (4, 1680)
# there are 24 points
# there are 24 points after filtering
# ransac count: 121
# angle is 1.8745829316738367 inlier ratio: 0.6666666666666666
# dense angle is 3.2016013518834687
# buffer size : 5
# -------------------------------------------------
# processing frame 673
# Get RT: (4, 1693)
# there are 15 points
# there are 15 points after filtering
# ransac count: 176
# angle is 17.293403310495066 inlier ratio: 0.7333333333333333
# -------------------------------------------------
# processing frame 674
# Get RT: (4, 1689)
# there are 19 points
# there are 19 points after filtering
# ransac count: 114
# angle is 1.5813201643332966 inlier ratio: 0.8947368421052632
# dense angle is 1.5644541953445705
# buffer size : 5
# -------------------------------------------------
# processing frame 675
# Get RT: (4, 1622)
# there are 4 points
# there are 4 points after filtering
# ransac count: 191
# angle is 7.013196496557696 inlier ratio: 1.0
# dense angle is 6.6368959378058205
# buffer size : 5
# -------------------------------------------------
# processing frame 676
# Get RT: (4, 1570)
# there are 25 points
# there are 25 points after filtering
# ransac count: 92
# angle is 1.7872194113664457 inlier ratio: 0.76
# dense angle is 1.486457901046647
# buffer size : 5
# -------------------------------------------------
# processing frame 677
# Get RT: (4, 1597)
# there are 22 points
# there are 22 points after filtering
# ransac count: 103
# angle is 2.108198471361654 inlier ratio: 0.6818181818181818
# dense angle is 2.0061580104245835
# buffer size : 5
# -------------------------------------------------
# processing frame 678
# Get RT: (4, 1621)
# there are 29 points
# there are 29 points after filtering
# ransac count: 137
# angle is 1.1566714971101348 inlier ratio: 0.8275862068965517
# dense angle is 1.9263557954843125
# buffer size : 5
# -------------------------------------------------
# processing frame 679
# Get RT: (4, 1644)
# there are 4 points
# there are 4 points after filtering
# ransac count: 186
# angle is 4.869411246803648 inlier ratio: 1.0
# dense angle is 4.618526792598203
# buffer size : 5
# -------------------------------------------------
# processing frame 680
# Get RT: (4, 1683)
# there are 5 points
# there are 5 points after filtering
# ransac count: 100
# angle is 2.422767783941744 inlier ratio: 1.0
# dense angle is 2.1615643820383252
# buffer size : 5
# -------------------------------------------------
# processing frame 681
# Get RT: (4, 1692)
# there are 20 points
# there are 20 points after filtering
# ransac count: 113
# angle is 5.083986126801448 inlier ratio: 0.7
# dense angle is 2.727448093253897
# buffer size : 5
# -------------------------------------------------
# processing frame 682
# Get RT: (4, 1722)
# there are 23 points
# there are 23 points after filtering
# ransac count: 103
# angle is 1.3379023485227388 inlier ratio: 0.6956521739130435
# dense angle is 1.9234566123128196
# buffer size : 5
# -------------------------------------------------
# processing frame 683
# Get RT: (4, 1763)
# there are 16 points
# there are 16 points after filtering
# ransac count: 191
# angle is 88.00360016916318 inlier ratio: 0.75
# -------------------------------------------------
# processing frame 684
# Get RT: (4, 1799)
# there are 0 points
# there are 0 points after filtering
# -------------------------------------------------
# processing frame 685
# Get RT: (4, 1837)
# there are 9 points
# there are 9 points after filtering
# ransac count: 134
# angle is 4.481547579136267 inlier ratio: 0.7777777777777778
# dense angle is 2.4239463692788683
# buffer size : 5
# -------------------------------------------------
# processing frame 686
# Get RT: (4, 1839)
# there are 3 points
# there are 3 points after filtering
# -------------------------------------------------
# processing frame 687
# Get RT: (4, 1904)
# there are 2 points
# there are 2 points after filtering
# -------------------------------------------------
# processing frame 688
# Get RT: (4, 1885)
# there are 6 points
# there are 6 points after filtering
# ransac count: 224
# angle is 5.87424382593802 inlier ratio: 1.0
# dense angle is 5.421216820907045
# buffer size : 5
# -------------------------------------------------
# processing frame 689
# Get RT: (4, 1926)
# there are 9 points
# there are 9 points after filtering
# ransac count: 41
# angle is 0.5631878602190329 inlier ratio: 0.7777777777777778
# dense angle is 2.7550990325978817
# buffer size : 5
# -------------------------------------------------
# processing frame 690
# Get RT: (4, 1961)
# there are 11 points
# there are 11 points after filtering
# ransac count: 0
# reducing points to 0
# -------------------------------------------------
# processing frame 691
# Get RT: (4, 2016)
# there are 23 points
# there are 23 points after filtering
# ransac count: 0
# reducing points to 2
# -------------------------------------------------
# processing frame 692
# Get RT: (4, 2137)
# there are 37 points
# there are 37 points after filtering
# ransac count: 0
# reducing points to 0
# -------------------------------------------------
# processing frame 693
# Get RT: (4, 2225)
# there are 35 points
# there are 35 points after filtering
# ransac count: 16
# angle is 4.7022988282611955 inlier ratio: 0.6857142857142857
# dense angle is 4.917732269696651
# buffer size : 5
# -------------------------------------------------
# processing frame 694
# Get RT: (4, 2253)
# there are 28 points
# there are 28 points after filtering
# ransac count: 0
# reducing points to 2
# -------------------------------------------------
# processing frame 695
# Get RT: (4, 2296)
# there are 3 points
# there are 3 points after filtering
# -------------------------------------------------
# processing frame 696
# Get RT: (4, 2258)
# there are 18 points
# there are 18 points after filtering
# ransac count: 0
# reducing points to 6
# angle is 6.2859943246375405 inlier ratio: 0.8333333333333334
# dense angle is 4.35560635657618
# buffer size : 5
# -------------------------------------------------
# processing frame 697
# Get RT: (4, 2355)
# there are 10 points
# there are 10 points after filtering
# ransac count: 0
# reducing points to 5
# -------------------------------------------------
# processing frame 698
# Get RT: (4, 2332)
# there are 9 points
# there are 9 points after filtering
# ransac count: 12
# angle is 13.664879536678685 inlier ratio: 0.7777777777777778
# -------------------------------------------------
# processing frame 699
# Get RT: (4, 2200)
# there are 45 points
# there are 45 points after filtering
# ransac count: 0
# reducing points to 0
# -------------------------------------------------
# processing frame 700
# Get RT: (4, 2206)
# there are 77 points
# there are 77 points after filtering
# ransac count: 0
# reducing points to 0
# -------------------------------------------------
# processing frame 701
# Get RT: (4, 2136)
# there are 136 points
# there are 136 points after filtering
# ransac count: 0
# reducing points to 9
# angle is 2.533157227781141 inlier ratio: 0.7777777777777778
# dense angle is 1.909039727971506
# buffer size : 5
# -------------------------------------------------
# processing frame 702
# Get RT: (4, 2097)
# there are 167 points
# there are 167 points after filtering
# ransac count: 0
# reducing points to 35
# -------------------------------------------------
# processing frame 703
# Get RT: (4, 2083)
# there are 152 points
# there are 152 points after filtering
# ransac count: 0
# reducing points to 49
# angle is 6.382228456449701 inlier ratio: 0.6326530612244898
# dense angle is 7.204726437216236
# buffer size : 5
# -------------------------------------------------
# processing frame 704
# Get RT: (4, 1975)
# there are 140 points
# there are 140 points after filtering
# ransac count: 0
# reducing points to 72
# angle is 6.070302332621274 inlier ratio: 0.6527777777777778
# dense angle is 5.650895046977698
# buffer size : 5
# -------------------------------------------------
# processing frame 705
# Get RT: (4, 1897)
# there are 105 points
# there are 105 points after filtering
# ransac count: 14
# angle is 4.456015928135105 inlier ratio: 0.6190476190476191
# dense angle is 5.559354419768698
# buffer size : 5
# -------------------------------------------------
# processing frame 706
# Get RT: (4, 1860)
# there are 72 points
# there are 72 points after filtering
# ransac count: 4
# angle is 6.681579206179847 inlier ratio: 0.625
# dense angle is 8.450367250018502
# buffer size : 5
# -------------------------------------------------
# processing frame 707
# Get RT: (4, 1799)
# there are 75 points
# there are 75 points after filtering
# ransac count: 0
# reducing points to 25
# angle is 5.57921519839193 inlier ratio: 0.72
# dense angle is 5.780506890141539
# buffer size : 5
# -------------------------------------------------
# processing frame 708
# Get RT: (4, 1832)
# there are 63 points
# there are 63 points after filtering
# ransac count: 0
# reducing points to 19
# angle is 7.434915412998882 inlier ratio: 0.7368421052631579
# dense angle is 7.219072357842668
# buffer size : 5
# -------------------------------------------------
# processing frame 709
# Get RT: (4, 1872)
# there are 107 points
# there are 107 points after filtering
# ransac count: 4
# angle is 1.969806750378921 inlier ratio: 0.616822429906542
# dense angle is 5.293795405643662
# buffer size : 5
# -------------------------------------------------
# processing frame 710
# Get RT: (4, 1828)
# there are 63 points
# there are 63 points after filtering
# ransac count: 17
# angle is 3.0433789061029026 inlier ratio: 0.6349206349206349
# dense angle is 4.449411867262813
# buffer size : 5
# -------------------------------------------------
# processing frame 711
# Get RT: (4, 1860)
# there are 76 points
# there are 76 points after filtering
# ransac count: 39
# angle is 6.467537201472887 inlier ratio: 0.6578947368421053
# dense angle is 7.309113413921767
# buffer size : 5
# -------------------------------------------------
# processing frame 712
# Get RT: (4, 1801)
# there are 71 points
# there are 71 points after filtering
# ransac count: 34
# angle is 9.802969872574751 inlier ratio: 0.7323943661971831
# dense angle is 8.442342860280089
# buffer size : 5
# -------------------------------------------------
# processing frame 713
# Get RT: (4, 1872)
# there are 77 points
# there are 77 points after filtering
# ransac count: 57
# angle is 8.58731983433976 inlier ratio: 0.7142857142857143
# dense angle is 8.004654747306784
# buffer size : 5
# -------------------------------------------------
# processing frame 714
# Get RT: (4, 1882)
# there are 73 points
# there are 73 points after filtering
# ransac count: 51
# angle is 8.164749512743787 inlier ratio: 0.6712328767123288
# dense angle is 7.4820292356438705
# buffer size : 5
# -------------------------------------------------
# processing frame 715
# Get RT: (4, 1808)
# there are 49 points
# there are 49 points after filtering
# ransac count: 13
# angle is 3.8040869459814797 inlier ratio: 0.6530612244897959
# dense angle is 5.436466039649087
# buffer size : 5
# -------------------------------------------------
# processing frame 716
# Get RT: (4, 1712)
# there are 69 points
# there are 69 points after filtering
# ransac count: 61
# angle is 0.4317689294009458 inlier ratio: 0.6956521739130435
# dense angle is 5.301630191135212
# buffer size : 5
# -------------------------------------------------
# processing frame 717
# Get RT: (4, 1683)
# there are 48 points
# there are 48 points after filtering
# ransac count: 55
# angle is 9.587943752852572 inlier ratio: 0.7291666666666666
# dense angle is 7.492566576889454
# buffer size : 5
# -------------------------------------------------
# processing frame 718
# Get RT: (4, 1626)
# there are 57 points
# there are 57 points after filtering
# ransac count: 80
# angle is 16.06132973189405 inlier ratio: 0.6491228070175439
# -------------------------------------------------
# processing frame 719
# Get RT: (4, 1640)
# there are 73 points
# there are 73 points after filtering
# ransac count: 5
# angle is 14.606180852081287 inlier ratio: 0.6438356164383562
# -------------------------------------------------
# processing frame 720
# Get RT: (4, 1635)
# there are 99 points
# there are 99 points after filtering
# ransac count: 11
# angle is 9.151892819475671 inlier ratio: 0.6565656565656566
# dense angle is 6.304713917658161
# buffer size : 5
# -------------------------------------------------
# processing frame 721
# Get RT: (4, 1710)
# there are 113 points
# there are 113 points after filtering
# ransac count: 34
# angle is 13.76709620470567 inlier ratio: 0.6194690265486725
# -------------------------------------------------
# processing frame 722
# Get RT: (4, 1753)
# there are 89 points
# there are 89 points after filtering
# ransac count: 44
# angle is 7.340351004488905 inlier ratio: 0.6404494382022472
# dense angle is 8.22345002169035
# buffer size : 5
# -------------------------------------------------
# processing frame 723
# Get RT: (4, 1749)
# there are 97 points
# there are 97 points after filtering
# ransac count: 45
# angle is 3.051725797429223 inlier ratio: 0.6597938144329897
# dense angle is 3.1088869716452145
# buffer size : 5
# -------------------------------------------------
# processing frame 724
# Get RT: (4, 1739)
# there are 117 points
# there are 117 points after filtering
# ransac count: 60
# angle is 11.051509627876957 inlier ratio: 0.6410256410256411
# -------------------------------------------------
# processing frame 725
# Get RT: (4, 1688)
# there are 95 points
# there are 95 points after filtering
# ransac count: 58
# angle is 9.268876262536265 inlier ratio: 0.7052631578947368
# dense angle is 10.58456445283324
# buffer size : 5
# -------------------------------------------------
# processing frame 726
# Get RT: (4, 1610)
# there are 66 points
# there are 66 points after filtering
# ransac count: 36
# angle is 2.4632047631710394 inlier ratio: 0.6515151515151515
# dense angle is 4.983885108409968
# buffer size : 5
# -------------------------------------------------
# processing frame 727
# Get RT: (4, 1598)
# there are 47 points
# there are 47 points after filtering
# ransac count: 56
# angle is 4.758186441446738 inlier ratio: 0.7021276595744681
# dense angle is 4.223759817570228
# buffer size : 5
# -------------------------------------------------
# processing frame 728
# Get RT: (4, 1621)
# there are 47 points
# there are 47 points after filtering
# ransac count: 70
# angle is 2.368487439195965 inlier ratio: 0.6808510638297872
# dense angle is 3.744205138719738
# buffer size : 5
# -------------------------------------------------
# processing frame 729
# Get RT: (4, 1526)
# there are 48 points
# there are 48 points after filtering
# ransac count: 52
# angle is 0.8189402973662051 inlier ratio: 0.7916666666666666
# dense angle is 2.2610713465670935
# buffer size : 5
# -------------------------------------------------
# processing frame 730
# Get RT: (4, 1602)
# there are 88 points
# there are 88 points after filtering
# ransac count: 93
# angle is 2.414111954846786 inlier ratio: 0.7045454545454546
# dense angle is 0.9214108261688495
# buffer size : 5
# -------------------------------------------------
# processing frame 731
# Get RT: (4, 1627)
# there are 83 points
# there are 83 points after filtering
# ransac count: 50
# angle is 1.92880108127389 inlier ratio: 0.6385542168674698
# dense angle is 2.795743857730907
# buffer size : 5
# -------------------------------------------------
# processing frame 732
# Get RT: (4, 1679)
# there are 101 points
# there are 101 points after filtering
# ransac count: 81
# angle is 3.2422481867772155 inlier ratio: 0.6732673267326733
# dense angle is 2.5632327509952026
# buffer size : 5
# -------------------------------------------------
# processing frame 733
# Get RT: (4, 1611)
# there are 114 points
# there are 114 points after filtering
# ransac count: 91
# angle is 0.45519120196996604 inlier ratio: 0.7017543859649122
# dense angle is 1.1657646640437436
# buffer size : 5
# -------------------------------------------------
# processing frame 734
# Get RT: (4, 1700)
# there are 129 points
# there are 129 points after filtering
# ransac count: 76
# angle is 1.5809894137821583 inlier ratio: 0.7751937984496124
# dense angle is 0.6531230078352966
# buffer size : 5
# -------------------------------------------------
# processing frame 735
# Get RT: (4, 1638)
# there are 114 points
# there are 114 points after filtering
# ransac count: 101
# angle is 3.552534318563025 inlier ratio: 0.6140350877192983
# dense angle is 2.07857182662547
# buffer size : 5
# -------------------------------------------------
# processing frame 736
# Get RT: (4, 1726)
# there are 85 points
# there are 85 points after filtering
# ransac count: 107
# angle is 3.9853830454792503 inlier ratio: 0.7058823529411765
# dense angle is 4.706554761937839
# buffer size : 5
# -------------------------------------------------
# processing frame 737
# Get RT: (4, 1747)
# there are 124 points
# there are 124 points after filtering
# ransac count: 117
# angle is 1.3480178961331861 inlier ratio: 0.7096774193548387
# dense angle is 0.954716656688118
# buffer size : 5
# -------------------------------------------------
# processing frame 738
# Get RT: (4, 1671)
# there are 91 points
# there are 91 points after filtering
# ransac count: 136
# angle is 3.286890983576388 inlier ratio: 0.6153846153846154
# dense angle is 2.1277855367606673
# buffer size : 5
# -------------------------------------------------
# processing frame 739
# Get RT: (4, 1596)
# there are 75 points
# there are 75 points after filtering
# ransac count: 130
# angle is 0.591955915240546 inlier ratio: 0.8133333333333334
# dense angle is 0.6441249113702657
# buffer size : 5
# -------------------------------------------------
# processing frame 740
# Get RT: (4, 1551)
# there are 55 points
# there are 55 points after filtering
# ransac count: 115
# angle is 2.3273244590516153 inlier ratio: 0.7636363636363637
# dense angle is 1.577433131867985
# buffer size : 5
# -------------------------------------------------
# processing frame 741
# Get RT: (4, 1660)
# there are 78 points
# there are 78 points after filtering
# ransac count: 105
# angle is 0.7912006747937562 inlier ratio: 0.8076923076923077
# dense angle is 1.041155085088277
# buffer size : 5
# -------------------------------------------------
# processing frame 742
# Get RT: (4, 1711)
# there are 81 points
# there are 81 points after filtering
# ransac count: 108
# angle is 1.8961853077976971 inlier ratio: 0.8765432098765432
# dense angle is 1.2236829904570095
# buffer size : 5
# -------------------------------------------------
# processing frame 743
# Get RT: (4, 1669)
# there are 101 points
# there are 101 points after filtering
# ransac count: 118
# angle is 3.9155066456333047 inlier ratio: 0.900990099009901
# dense angle is 2.6009502206893176
# buffer size : 5
# -------------------------------------------------
# processing frame 744
# Get RT: (4, 1659)
# there are 104 points
# there are 104 points after filtering
# ransac count: 141
# angle is 2.8136701080115327 inlier ratio: 0.6153846153846154
# dense angle is 1.7881928214615084
# buffer size : 5
# -------------------------------------------------
# processing frame 745
# Get RT: (4, 1629)
# there are 108 points
# there are 108 points after filtering
# ransac count: 79
# angle is 2.0742092005212447 inlier ratio: 0.7407407407407407
# dense angle is 1.6783121574965694
# buffer size : 5
# -------------------------------------------------
# processing frame 746
# Get RT: (4, 1605)
# there are 81 points
# there are 81 points after filtering
# ransac count: 78
# angle is 4.755042828163799 inlier ratio: 0.6666666666666666
# dense angle is 2.207554890530562
# buffer size : 5
# -------------------------------------------------
# processing frame 747
# Get RT: (4, 1628)
# there are 23 points
# there are 23 points after filtering
# ransac count: 72
# angle is 6.377329324310186 inlier ratio: 0.7391304347826086
# dense angle is 6.671503821322885
# buffer size : 5
# -------------------------------------------------
# processing frame 748
# Get RT: (4, 1649)
# there are 61 points
# there are 61 points after filtering
# ransac count: 132
# angle is 1.792127325656516 inlier ratio: 0.7868852459016393
# dense angle is 1.1884548970483637
# buffer size : 5
# -------------------------------------------------
# processing frame 749
# Get RT: (4, 1668)
# there are 74 points
# there are 74 points after filtering
# ransac count: 108
# angle is 4.207192665330152 inlier ratio: 0.6486486486486487
# dense angle is 1.718167228894551
# buffer size : 5
# -------------------------------------------------
# Total ransc count: 87/99

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
ax = plt.gca()
plt.yticks(np.arange(0, 2, 0.05))
plt.ylim(0, 1.5)

results2 = np.array(results)
df = pd.DataFrame({'scale_roi': results2[:,0], 
                   'scale_dense': results2[:,1], 
                    'frame': np.arange(start, end)
                  })

df_truth[start:end]['translation'].plot(ax=ax, label='Ground truth', grid=True)
df.plot.scatter(x='frame', y='scale_roi', c='r', ax=ax, alpha=.25, grid=True)
df.plot.scatter(x='frame', y='scale_dense', c='g', ax=ax, alpha=.25, grid=True)

# %%
results = pd.concat([df.set_index('frame'), df_truth[start:end]['translation']], axis=1, sort=False)
valid_results = results[results['scale_dense'] != 0]
err = (valid_results['scale_dense'] - valid_results['translation'])**2
print("rmse: {}".format(np.sqrt(err.mean())))
print("total valid: {}".format(valid_results.shape[0]))
# Out:
# rmse: 0.09295054760752057
# total valid: 77

# %%
df
# Out:
#     scale_roi  scale_dense  frame
# 0    1.357812     1.339222    651
# 1    1.169876     1.175504    652
# 2    1.240936     1.243417    653
# 3    1.116571     1.166888    654
# 4    0.000000     0.000000    655
# ..        ...          ...    ...
# 94   1.157465     1.156029    745
# 95   1.018929     1.123487    746
# 96   1.058740     1.091362    747
# 97   1.142690     1.172148    748
# 98   1.203936     1.239821    749
#
# [99 rows x 3 columns]

# %%
df_truth[start:end]['translation']
# Out:
# 651    1.249731
# 652    1.240841
# 653    1.230907
# 654    1.222307
# 655    1.214501
#          ...
# 745    1.167904
# 746    1.188299
# 747    1.203518
# 748    1.219824
# 749    1.231240
# Name: translation, Length: 99, dtype: float64

# %%
results
# Out:
#      scale_roi  scale_dense  translation
# 651   1.357812     1.339222     1.249731
# 652   1.169876     1.175504     1.240841
# 653   1.240936     1.243417     1.230907
# 654   1.116571     1.166888     1.222307
# 655   0.000000     0.000000     1.214501
# ..         ...          ...          ...
# 745   1.157465     1.156029     1.167904
# 746   1.018929     1.123487     1.188299
# 747   1.058740     1.091362     1.203518
# 748   1.142690     1.172148     1.219824
# 749   1.203936     1.239821     1.231240
#
# [99 rows x 3 columns]
